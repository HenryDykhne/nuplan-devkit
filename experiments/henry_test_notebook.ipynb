# %% [markdown]
# # Creating a new planner in nuPlan <a name="introduction"></a>

# %% [markdown]
# ## Setup

# %%
import asyncio
import itertools
import logging
import random
import nest_asyncio

nest_asyncio.apply()  # must be run at the start of every notebook to patch the event loop to allow nesting, eg. so we can run asyncio.run from within a notebook.

# from IPython.core.display import display, HTML
# from bokeh.io import output_notebook

# %%
import os
from pathlib import Path
import tempfile

from shutil import rmtree
from typing import List, Optional, Union

# %%
# nest_asyncio.apply()
# output_notebook()
# display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
# display(HTML("<style>.container { width:100% !important; }</style>"))

# %%
# %cd ..

# Adjust your env variables here if nescesary

# %env NUPLAN_DATA_ROOT=../../../datasets/nuplan/dataset
# %env NUPLAN_MAPS_ROOT=../../data/nuplan/maps
# %env NUPLAN_EXP_ROOT=../../data/nuplan/exp
# %env NUPLAN_DEVKIT_ROOT=../../nuplan-devkit/
# %pwd
# Out:
# env: NUPLAN_DATA_ROOT=../../../datasets/nuplan/dataset
# env: NUPLAN_MAPS_ROOT=../../data/nuplan/maps
# env: NUPLAN_EXP_ROOT=../../data/nuplan/exp
# env: NUPLAN_DEVKIT_ROOT=../../nuplan-devkit/
# '/home/ehdykhne/nuplan-devkit/experiments'

# %%
import hydra
import pytorch_lightning as pl
from omegaconf import DictConfig, OmegaConf

from nuplan.common.utils.s3_utils import is_s3_path
from nuplan.planning.script.builders.simulation_builder import build_simulations
from nuplan.planning.script.builders.simulation_callback_builder import (
    build_callbacks_worker,
    build_simulation_callbacks,
)
from nuplan.planning.script.utils import (
    run_runners,
    set_default_path,
    set_up_common_builder,
)
from nuplan.planning.simulation.planner.abstract_planner import AbstractPlanner

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# If set, use the env. variable to overwrite the default dataset and experiment paths
set_default_path()

# If set, use the env. variable to overwrite the Hydra config
CONFIG_PATH = os.getenv("NUPLAN_HYDRA_CONFIG_PATH", "config/simulation")

if os.environ.get("NUPLAN_HYDRA_CONFIG_PATH") is not None:
    CONFIG_PATH = os.path.join("../../../../", CONFIG_PATH)

if os.path.basename(CONFIG_PATH) != "simulation":
    CONFIG_PATH = os.path.join(CONFIG_PATH, "simulation")
CONFIG_NAME = "default_simulation"

# %% [markdown]
# # Simulating the planner <a name="simulation"></a>

# %% [markdown]
# ## Prepare the simulation config

# %%
from tutorials.utils.tutorial_utils import construct_simulation_hydra_paths

# Location of paths with all simulation configs
BASE_CONFIG_PATH = os.path.join(
    os.getenv("NUPLAN_TUTORIAL_PATH", ""), "../nuplan/planning/script"
)
simulation_hydra_paths = construct_simulation_hydra_paths(BASE_CONFIG_PATH)

# Create a temporary directory to store the simulation artifacts

scenario_types = [
    "accelerating_at_traffic_light_with_lead",
    "crossed_by_bike",
    "crossed_by_vehicle",
    # "on_intersection",
    # "on_stopline_crosswalk",
    # "on_stopline_stop_sign",
    # "on_stopline_traffic_light",
    "on_traffic_light_intersection",
    # "starting_protected_cross_turn",
    # "starting_protected_noncross_turn",
    # "starting_right_turn",
    "starting_straight_stop_sign_intersection_traversal",
    "starting_straight_traffic_light_intersection_traversal",
    # "starting_u_turn",
    "starting_unprotected_cross_turn",
    "starting_unprotected_noncross_turn",
    # "stationary_at_crosswalk",
    # "stationary_at_traffic_light_with_lead",
    # "stationary_at_traffic_light_without_lead",
    # "traversing_crosswalk",
    # "traversing_intersection",
    "traversing_traffic_light_intersection",
]

# scenario_types = ['stationary_at_traffic_light_without_lead']

scenario_builder = "val"  # [nuplan (uses trainval), nuplan_mini, test, val, train_boston, train_pittsburgh, train_singapore]
DATASET_PARAMS = [
    f"scenario_builder={scenario_builder}",
    "scenario_filter=all_scenarios",  # [all_scenarios, val14_split]
    # f"scenario_filter.scenario_types={scenario_types}",  # there are 70 scenario types in the trainingset and 58 in the validation set including "unknown" which make up the majority
    # "scenario_filter.ego_displacement_minimum_m=10",  # use scenarios where the ego vehicle moves at least 10m
    #    'scenario_filter.remove_invalid_goals=true',  # remove scenarios where the goal is not invalid
    # "scenario_filter.ego_start_speed_threshold=5",  # Exclusive threshold that the ego's speed must rise above (meters per second) for scenario to be kept
    #    'scenario_filter.stop_speed_threshold=10',  # Inclusive threshold that the ego's speed must fall below (meters per second) for scenario to be kept:
    # "scenario_filter.map_names=[us-pa-pittsburgh-hazelwood]",  # [sg-one-north, us-ma-boston, us-pa-pittsburgh-hazelwood, us-nv-las-vegas-strip]
    # "scenario_filter.num_scenarios_per_type=200",  # use 10 scenarios per scenario type
    "scenario_filter.scenario_tokens=['df4441167a6f54f8']",  # List of scenarios to include (token)
    #    'scenario_filter.log_names=["2021.08.24.18.07.48_veh-45_01504_01722"]', # specific scenrios to simulate
    # "scenario_filter.limit_total_scenarios=0.05",  # use n total scenarios if int, or if float smaller than 1, use n as a fraction of total scenarios (changes sampling frequency, unchanged leaves the frequency at 20Hz)
]
ckpt_dir = "/home/ehdykhne/nuplan-devkit/experiments/pretrained_checkpoints/gc_pgp_checkpoint.ckpt"
hybrid_ckpt = "/home/sacardoz/checkpoints/pdm_offset_checkpoint.ckpt"
#'/home/sacardoz/checkpoints/urbandriver_checkpoint.ckpt'
# "/home/sacardoz/tutorial_vector_framework/training_simple_vector_experiment/train_default_simple_vector/2023.11.23.09.55.21/best_model/epoch.ckpt"
# "/home/sacardoz/training_raster_experiment/train_default_raster/2023.11.23.07.36.36/best_model/epoch.ckpt"
# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=simulation_hydra_paths.config_path)

# Compose the configuration
cfg = hydra.compose(
    config_name=simulation_hydra_paths.config_name,
    overrides=[
        "+simulation=closed_loop_multiagent",  # [open_loop_boxes, closed_loop_nonreactive_agents, closed_loop_reactive_agents, closed_loop_multiagent]
        "planner=ml_planner",
        # f"planner.pdm_closed_planner.checkpoint_path={hybrid_ckpt}",
        #'observation.model_config=${model}',
        # f'observation.checkpoint_path={ckpt_dir}',
        "model=gc_pgp_model",
        "planner.ml_planner.model_config=${model}",
        f"planner.ml_planner.checkpoint_path={ckpt_dir}",
        f"observation.planner_type=ml",
        "observation.model_config=${model}",
        f"observation.checkpoint_path={ckpt_dir}",
        # f"observation.pdm_hybrid_ckpt={hybrid_ckpt}",
        f"observation.occlusion_cfg.occlusion=true",
        f"observation.occlusion_cfg.manager_type=wedge",
        f"+observation.occlusion_cfg.uncloak_reaction_time=1.5",
        f"+observation.occlusion_cfg.notice_threshold=1.0",
        "+occlusion=true",
        "+occlusion.manager_type=wedge",  # options: [range, shadow, wedge]
        "+occlusion.uncloak_reaction_time=1.5",
        "+occlusion.notice_threshold=1.0",
        "worker=sequential",  # [sequential, ray_distributed]
        "hydra.searchpath=[pkg://tuplan_garage.planning.script.config.common, pkg://tuplan_garage.planning.script.config.simulation, pkg://nuplan.planning.script.config.common, pkg://nuplan.planning.script.experiments]",
        *DATASET_PARAMS,
    ],
)

output_folder = cfg.output_dir
print('output_folder = "' + output_folder + '"')

# '+simulation=closed_loop_multiagent',
#     #'model=urban_driver_open_loop_model',
#     'planner=pdm_hybrid_planner',
#     f"planner.pdm_hybrid_planner.checkpoint_path={hybrid_ckpt}" ,
#     #'observation.model_config=${model}',
#     #f'observation.checkpoint_path={ckpt_dir}',
#     f'observation.planner_type=pdm_hybrid',
#     f'observation.pdm_hybrid_ckpt={hybrid_ckpt}',
#     f'observation.occlusion_cfg.occlusion=true',
#     f'observation.occlusion_cfg.manager_type=wedge',
#     'worker=sequential',
#     '+occlusion=true',
#     '+occlusion.manager_type=wedge', #options: [range, shadow, wedge]
#     "hydra.searchpath=[pkg://tuplan_garage.planning.script.config.common, pkg://tuplan_garage.planning.script.config.simulation, pkg://nuplan.planning.script.config.common, pkg://nuplan.planning.script.experiments]",
# Out:
# output_folder = "../../data/nuplan/exp/exp/simulation/closed_loop_multiagent/2024.01.03.14.19.08"

# %%
from nuplan.planning.script.run_simulation import build_simulation_runners
from nuplan.common.actor_state.tracked_objects_types import (
    AGENT_TYPES,
    STATIC_OBJECT_TYPES,
    TrackedObjectType,
)

# Run the simulation loop (real-time visualization not yet supported, see next section for visualization)
runners, common_builder, cfg = build_simulation_runners(cfg)
# Out:
# Global seed set to 0
# INFO:nuplan.planning.script.builders.main_callback_builder:Building MultiMainCallback...
# INFO:nuplan.planning.script.builders.main_callback_builder:Building MultiMainCallback: 4...DONE!
# 2024-01-02 11:51:21,204 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2024-01-02 11:51:21,205 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: Sequential
# 2024-01-02 11:51:21,205 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 1
# Number of GPUs per node: 0
# Number of threads across all nodes: 1
# 2024-01-02 11:51:21,205 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2024-01-02 11:51:21,205 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2024-01-02 11:51:21,205 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: ../../data/nuplan/exp/exp/simulation/closed_loop_multiagent/2024.01.02.11.51.20
#
# 2024-01-02 11:51:21,206 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2024-01-02 11:51:21,206 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2024-01-02 11:51:21,206 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2024-01-02 11:51:21,206 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:49}  Building simulations...
# 2024-01-02 11:51:21,206 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:55}  Extracting scenarios...
# 2024-01-02 11:51:21,207 INFO {/home/ehdykhne/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2024-01-02 11:51:21,207 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2024-01-02 11:51:21,223 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2024-01-02 11:51:21,223 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2024-01-02 11:51:21,224 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2024-01-02 11:51:21,609 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...
# 2024-01-02 11:51:21,760 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:78}  Building metric engines...DONE
# 2024-01-02 11:51:21,761 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:82}  Building simulations from 1 scenarios...
# 2024-01-02 11:51:21,763 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2024-01-02 11:51:21,830 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2024-01-02 11:51:22,060 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2024-01-02 11:51:22,066 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2024-01-02 11:51:22,562 INFO {/home/ehdykhne/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:142}  Building simulations...DONE!

# %%
runner = runners[0]

# %%
from nuplan.common.actor_state.agent import Agent
from nuplan.common.actor_state.oriented_box import OrientedBox
from nuplan.common.actor_state.scene_object import SceneObjectMetadata
from nuplan.common.actor_state.state_representation import StateSE2, StateVector2D
import math

speed = 5.2
angle = 1.25
inserted_agent = Agent(
    tracked_object_type=TrackedObjectType.VEHICLE,
    oriented_box=OrientedBox(StateSE2(587505.03, 4475691.75, angle), 5, 2, 2),
    velocity=StateVector2D(speed * math.cos(angle), speed * math.sin(angle)),
    metadata=SceneObjectMetadata(1623707858950113, "inserted", -2, "inserted"),
    angular_velocity=0.0,
)

inserted_goal = StateSE2(587567, 4475882, 1.25)
insertion_time = 0.0

# %%
runner.simulation.callback.on_simulation_start(runner.simulation.setup)

# Initialize all simulations
runner._initialize()

while runner.simulation.is_simulation_running():
    if runner.simulation._time_controller.get_iteration().index == insertion_time:
        iter = runner.simulation._time_controller.get_iteration()
        runner.simulation._observations.add_agent_to_scene(
            inserted_agent, inserted_goal, iter.time_point, runner.simulation
        )

    # Execute specific callback
    runner.simulation.callback.on_step_start(runner.simulation.setup, runner.planner)

    # Perform step
    planner_input = runner._simulation.get_planner_input()

    # Execute specific call+back
    runner._simulation.callback.on_planner_start(
        runner.simulation.setup, runner.planner
    )

    # Plan path based on all planner's inputs
    trajectory = runner.planner.compute_trajectory(planner_input)

    # Propagate simulation based on planner trajectory
    runner._simulation.callback.on_planner_end(
        runner.simulation.setup, runner.planner, trajectory
    )

    iteration = runner.simulation._time_controller.get_iteration()
    print(iteration)
    runner.simulation.propagate(trajectory)
    # Execute specific callback
    runner.simulation.callback.on_step_end(
        runner.simulation.setup, runner.planner, runner.simulation.history.last()
    )

runner.simulation.callback.on_simulation_end(
    runner.simulation.setup, runner.planner, runner.simulation.history
)
# Out:
# hi 0.0
# SimulationIteration(time_point=TimePoint(time_us=1629836927500525), index=0)
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.0
# hi 0.09994697570800781
# SimulationIteration(time_point=TimePoint(time_us=1629836927600472), index=1)
# hi 0.09994697570800781
# hi 0.09994697570800781
# hi 0.09994697570800781
# hi 0.09994697570800781
# hi 0.09994697570800781
# hi 0.09994697570800781
# hi 0.09994697570800781
# hi 0.09994697570800781
# hi 0.19988703727722168
# SimulationIteration(time_point=TimePoint(time_us=1629836927700412), index=2)
# hi 0.19988703727722168
# hi 0.19988703727722168
# hi 0.19988703727722168
# hi 0.19988703727722168
# hi 0.19988703727722168
# hi 0.19988703727722168
# hi 0.19988703727722168
# hi 0.19988703727722168
# hi 0.2998189926147461
# SimulationIteration(time_point=TimePoint(time_us=1629836927800344), index=3)
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.2998189926147461
# hi 0.3997509479522705
# SimulationIteration(time_point=TimePoint(time_us=1629836927900276), index=4)
# hi 0.3997509479522705
# hi 0.3997509479522705
# hi 0.3997509479522705
# hi 0.3997509479522705
# hi 0.3997509479522705
# hi 0.3997509479522705
# hi 0.3997509479522705
# hi 0.3997509479522705
# hi 0.49968695640563965
# SimulationIteration(time_point=TimePoint(time_us=1629836928000212), index=5)
# hi 0.49968695640563965
# hi 0.49968695640563965
# hi 0.49968695640563965
# hi 0.49968695640563965
# hi 0.49968695640563965
# hi 0.49968695640563965
# hi 0.49968695640563965
# hi 0.49968695640563965
# hi 0.5996239185333252
# SimulationIteration(time_point=TimePoint(time_us=1629836928100149), index=6)
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.5996239185333252
# hi 0.6995608806610107
# SimulationIteration(time_point=TimePoint(time_us=1629836928200086), index=7)
# hi 0.6995608806610107
# hi 0.6995608806610107
# hi 0.6995608806610107
# hi 0.6995608806610107
# hi 0.6995608806610107
# hi 0.6995608806610107
# hi 0.6995608806610107
# hi 0.6995608806610107
# hi 0.6995608806610107
# hi 0.7994949817657471
# SimulationIteration(time_point=TimePoint(time_us=1629836928300020), index=8)
# hi 0.7994949817657471
# hi 0.7994949817657471
# hi 0.7994949817657471
# hi 0.7994949817657471
# hi 0.7994949817657471
# hi 0.7994949817657471
# hi 0.7994949817657471
# hi 0.7994949817657471
# hi 0.7994949817657471
# hi 0.8994319438934326
# SimulationIteration(time_point=TimePoint(time_us=1629836928399957), index=9)
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.8994319438934326
# hi 0.9993598461151123
# SimulationIteration(time_point=TimePoint(time_us=1629836928499885), index=10)
# hi 0.9993598461151123
# hi 0.9993598461151123
# hi 0.9993598461151123
# hi 0.9993598461151123
# hi 0.9993598461151123
# hi 0.9993598461151123
# hi 0.9993598461151123
# hi 0.9993598461151123
# hi 0.9993598461151123
# hi 1.0992770195007324
# SimulationIteration(time_point=TimePoint(time_us=1629836928599802), index=11)
# hi 1.0992770195007324
# hi 1.0992770195007324
# hi 1.0992770195007324
# hi 1.0992770195007324
# hi 1.0992770195007324
# hi 1.0992770195007324
# hi 1.0992770195007324
# hi 1.0992770195007324
# hi 1.0992770195007324
# hi 1.1991829872131348
# SimulationIteration(time_point=TimePoint(time_us=1629836928699708), index=12)
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.1991829872131348
# hi 1.299088954925537
# SimulationIteration(time_point=TimePoint(time_us=1629836928799614), index=13)
# hi 1.299088954925537
# hi 1.299088954925537
# hi 1.299088954925537
# hi 1.299088954925537
# hi 1.299088954925537
# hi 1.299088954925537
# hi 1.299088954925537
# hi 1.299088954925537
# hi 1.299088954925537
# hi 1.3989999294281006
# SimulationIteration(time_point=TimePoint(time_us=1629836928899525), index=14)
# hi 1.3989999294281006
# hi 1.3989999294281006
# hi 1.3989999294281006
# hi 1.3989999294281006
# hi 1.3989999294281006
# hi 1.3989999294281006
# hi 1.3989999294281006
# hi 1.3989999294281006
# hi 1.3989999294281006
# hi 1.4989080429077148
# SimulationIteration(time_point=TimePoint(time_us=1629836928999433), index=15)
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.4989080429077148
# hi 1.5988118648529053
# SimulationIteration(time_point=TimePoint(time_us=1629836929099337), index=16)
# hi 1.5988118648529053
# hi 1.5988118648529053
# hi 1.5988118648529053
# hi 1.5988118648529053
# hi 1.5988118648529053
# hi 1.5988118648529053
# hi 1.5988118648529053
# hi 1.5988118648529053
# hi 1.5988118648529053
# hi 1.6987388134002686
# SimulationIteration(time_point=TimePoint(time_us=1629836929199264), index=17)
# hi 1.6987388134002686
# hi 1.6987388134002686
# hi 1.6987388134002686
# hi 1.6987388134002686
# hi 1.6987388134002686
# hi 1.6987388134002686
# hi 1.6987388134002686
# hi 1.6987388134002686
# hi 1.6987388134002686
# hi 1.798703908920288
# SimulationIteration(time_point=TimePoint(time_us=1629836929299229), index=18)
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.798703908920288
# hi 1.8986949920654297
# SimulationIteration(time_point=TimePoint(time_us=1629836929399220), index=19)
# hi 1.8986949920654297
# hi 1.8986949920654297
# hi 1.8986949920654297
# hi 1.8986949920654297
# hi 1.8986949920654297
# hi 1.8986949920654297
# hi 1.8986949920654297
# hi 1.8986949920654297
# hi 1.8986949920654297
# hi 1.9987189769744873
# SimulationIteration(time_point=TimePoint(time_us=1629836929499244), index=20)
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 1.9987189769744873
# hi 2.098780870437622
# SimulationIteration(time_point=TimePoint(time_us=1629836929599306), index=21)
# hi 2.098780870437622
# hi 2.098780870437622
# hi 2.098780870437622
# hi 2.098780870437622
# hi 2.098780870437622
# hi 2.098780870437622
# hi 2.098780870437622
# hi 2.098780870437622
# hi 2.098780870437622
# hi 2.1988558769226074
# SimulationIteration(time_point=TimePoint(time_us=1629836929699381), index=22)
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.1988558769226074
# hi 2.2989280223846436
# SimulationIteration(time_point=TimePoint(time_us=1629836929799453), index=23)
# hi 2.2989280223846436
# hi 2.2989280223846436
# hi 2.2989280223846436
# hi 2.2989280223846436
# hi 2.2989280223846436
# hi 2.2989280223846436
# hi 2.2989280223846436
# hi 2.2989280223846436
# hi 2.2989280223846436
# hi 2.398991823196411
# SimulationIteration(time_point=TimePoint(time_us=1629836929899517), index=24)
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.398991823196411
# hi 2.4990530014038086
# SimulationIteration(time_point=TimePoint(time_us=1629836929999578), index=25)
# hi 2.4990530014038086
# hi 2.4990530014038086
# hi 2.4990530014038086
# hi 2.4990530014038086
# hi 2.4990530014038086
# hi 2.4990530014038086
# hi 2.4990530014038086
# hi 2.4990530014038086
# hi 2.4990530014038086
# hi 2.599112033843994
# SimulationIteration(time_point=TimePoint(time_us=1629836930099637), index=26)
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.599112033843994
# hi 2.699180841445923
# SimulationIteration(time_point=TimePoint(time_us=1629836930199706), index=27)
# hi 2.699180841445923
# hi 2.699180841445923
# hi 2.699180841445923
# hi 2.699180841445923
# hi 2.699180841445923
# hi 2.699180841445923
# hi 2.699180841445923
# hi 2.699180841445923
# hi 2.699180841445923
# hi 2.799259901046753
# SimulationIteration(time_point=TimePoint(time_us=1629836930299785), index=28)
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.799259901046753
# hi 2.8993418216705322
# SimulationIteration(time_point=TimePoint(time_us=1629836930399867), index=29)
# hi 2.8993418216705322
# hi 2.8993418216705322
# hi 2.8993418216705322
# hi 2.8993418216705322
# hi 2.8993418216705322
# hi 2.8993418216705322
# hi 2.8993418216705322
# hi 2.8993418216705322
# hi 2.8993418216705322
# hi 2.9994168281555176
# SimulationIteration(time_point=TimePoint(time_us=1629836930499942), index=30)
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 2.9994168281555176
# hi 3.0994980335235596
# SimulationIteration(time_point=TimePoint(time_us=1629836930600023), index=31)
# hi 3.0994980335235596
# hi 3.0994980335235596
# hi 3.0994980335235596
# hi 3.0994980335235596
# hi 3.0994980335235596
# hi 3.0994980335235596
# hi 3.0994980335235596
# hi 3.0994980335235596
# hi 3.0994980335235596
# hi 3.199589967727661
# SimulationIteration(time_point=TimePoint(time_us=1629836930700115), index=32)
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.199589967727661
# hi 3.2996959686279297
# SimulationIteration(time_point=TimePoint(time_us=1629836930800221), index=33)
# hi 3.2996959686279297
# hi 3.2996959686279297
# hi 3.2996959686279297
# hi 3.2996959686279297
# hi 3.2996959686279297
# hi 3.2996959686279297
# hi 3.2996959686279297
# hi 3.2996959686279297
# hi 3.2996959686279297
# hi 3.3998119831085205
# SimulationIteration(time_point=TimePoint(time_us=1629836930900337), index=34)
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.3998119831085205
# hi 3.4999279975891113
# SimulationIteration(time_point=TimePoint(time_us=1629836931000453), index=35)
# hi 3.4999279975891113
# hi 3.4999279975891113
# hi 3.4999279975891113
# hi 3.4999279975891113
# hi 3.4999279975891113
# hi 3.4999279975891113
# hi 3.4999279975891113
# hi 3.4999279975891113
# hi 3.4999279975891113
# hi 3.600024938583374
# SimulationIteration(time_point=TimePoint(time_us=1629836931100550), index=36)
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.600024938583374
# hi 3.7001030445098877
# SimulationIteration(time_point=TimePoint(time_us=1629836931200628), index=37)
# hi 3.7001030445098877
# hi 3.7001030445098877
# hi 3.7001030445098877
# hi 3.7001030445098877
# hi 3.7001030445098877
# hi 3.7001030445098877
# hi 3.7001030445098877
# hi 3.7001030445098877
# hi 3.7001030445098877
# hi 3.800168991088867
# SimulationIteration(time_point=TimePoint(time_us=1629836931300694), index=38)
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.800168991088867
# hi 3.900202989578247
# SimulationIteration(time_point=TimePoint(time_us=1629836931400728), index=39)
# hi 3.900202989578247
# hi 3.900202989578247
# hi 3.900202989578247
# hi 3.900202989578247
# hi 3.900202989578247
# hi 3.900202989578247
# hi 3.900202989578247
# hi 3.900202989578247
# hi 3.900202989578247
# hi 4.000211000442505
# SimulationIteration(time_point=TimePoint(time_us=1629836931500736), index=40)
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.000211000442505
# hi 4.10020899772644
# SimulationIteration(time_point=TimePoint(time_us=1629836931600734), index=41)
# hi 4.10020899772644
# hi 4.10020899772644
# hi 4.10020899772644
# hi 4.10020899772644
# hi 4.10020899772644
# hi 4.10020899772644
# hi 4.10020899772644
# hi 4.10020899772644
# hi 4.200201034545898
# SimulationIteration(time_point=TimePoint(time_us=1629836931700726), index=42)
# hi 4.200201034545898
# hi 4.200201034545898
# hi 4.200201034545898
# hi 4.200201034545898
# hi 4.200201034545898
# hi 4.200201034545898
# hi 4.200201034545898
# hi 4.200201034545898
# hi 4.200201034545898
# hi 4.300184011459351
# SimulationIteration(time_point=TimePoint(time_us=1629836931800709), index=43)
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.300184011459351
# hi 4.400131940841675
# SimulationIteration(time_point=TimePoint(time_us=1629836931900657), index=44)
# hi 4.400131940841675
# hi 4.400131940841675
# hi 4.400131940841675
# hi 4.400131940841675
# hi 4.400131940841675
# hi 4.400131940841675
# hi 4.400131940841675
# hi 4.400131940841675
# hi 4.500056982040405
# SimulationIteration(time_point=TimePoint(time_us=1629836932000582), index=45)
# hi 4.500056982040405
# hi 4.500056982040405
# hi 4.500056982040405
# hi 4.500056982040405
# hi 4.500056982040405
# hi 4.500056982040405
# hi 4.500056982040405
# hi 4.500056982040405
# hi 4.500056982040405
# hi 4.599977016448975
# SimulationIteration(time_point=TimePoint(time_us=1629836932100502), index=46)
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.599977016448975
# hi 4.699892044067383
# SimulationIteration(time_point=TimePoint(time_us=1629836932200417), index=47)
# hi 4.699892044067383
# hi 4.699892044067383
# hi 4.699892044067383
# hi 4.699892044067383
# hi 4.699892044067383
# hi 4.699892044067383
# hi 4.699892044067383
# hi 4.699892044067383
# hi 4.699892044067383
# hi 4.799799919128418
# SimulationIteration(time_point=TimePoint(time_us=1629836932300325), index=48)
# hi 4.799799919128418
# hi 4.799799919128418
# hi 4.799799919128418
# hi 4.799799919128418
# hi 4.799799919128418
# hi 4.799799919128418
# hi 4.799799919128418
# hi 4.799799919128418
# hi 4.799799919128418
# hi 4.799799919128418
# hi 4.899708032608032
# SimulationIteration(time_point=TimePoint(time_us=1629836932400233), index=49)
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.899708032608032
# hi 4.9996178150177
# SimulationIteration(time_point=TimePoint(time_us=1629836932500143), index=50)
# hi 4.9996178150177
# hi 4.9996178150177
# hi 4.9996178150177
# hi 4.9996178150177
# hi 4.9996178150177
# hi 4.9996178150177
# hi 4.9996178150177
# hi 4.9996178150177
# hi 4.9996178150177
# hi 5.099535942077637
# SimulationIteration(time_point=TimePoint(time_us=1629836932600061), index=51)
# hi 5.099535942077637
# hi 5.099535942077637
# hi 5.099535942077637
# hi 5.099535942077637
# hi 5.099535942077637
# hi 5.099535942077637
# hi 5.099535942077637
# hi 5.099535942077637
# hi 5.099535942077637
# hi 5.099535942077637
# hi 5.199450969696045
# SimulationIteration(time_point=TimePoint(time_us=1629836932699976), index=52)
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.199450969696045
# hi 5.299363851547241
# SimulationIteration(time_point=TimePoint(time_us=1629836932799889), index=53)
# hi 5.299363851547241
# hi 5.299363851547241
# hi 5.299363851547241
# hi 5.299363851547241
# hi 5.299363851547241
# hi 5.299363851547241
# hi 5.299363851547241
# hi 5.299363851547241
# hi 5.399276971817017
# SimulationIteration(time_point=TimePoint(time_us=1629836932899802), index=54)
# hi 5.399276971817017
# hi 5.399276971817017
# hi 5.399276971817017
# hi 5.399276971817017
# hi 5.399276971817017
# hi 5.399276971817017
# hi 5.399276971817017
# hi 5.399276971817017
# hi 5.399276971817017
# hi 5.499189853668213
# SimulationIteration(time_point=TimePoint(time_us=1629836932999715), index=55)
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.499189853668213
# hi 5.599102020263672
# SimulationIteration(time_point=TimePoint(time_us=1629836933099627), index=56)
# hi 5.599102020263672
# hi 5.599102020263672
# hi 5.599102020263672
# hi 5.599102020263672
# hi 5.599102020263672
# hi 5.599102020263672
# hi 5.599102020263672
# hi 5.599102020263672
# hi 5.599102020263672
# hi 5.699031829833984
# SimulationIteration(time_point=TimePoint(time_us=1629836933199557), index=57)
# hi 5.699031829833984
# hi 5.699031829833984
# hi 5.699031829833984
# hi 5.699031829833984
# hi 5.699031829833984
# hi 5.699031829833984
# hi 5.699031829833984
# hi 5.699031829833984
# hi 5.699031829833984
# hi 5.798979997634888
# SimulationIteration(time_point=TimePoint(time_us=1629836933299505), index=58)
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.798979997634888
# hi 5.898967027664185
# SimulationIteration(time_point=TimePoint(time_us=1629836933399492), index=59)
# hi 5.898967027664185
# hi 5.898967027664185
# hi 5.898967027664185
# hi 5.898967027664185
# hi 5.898967027664185
# hi 5.898967027664185
# hi 5.898967027664185
# hi 5.898967027664185
# hi 5.898967027664185
# hi 5.998992919921875
# SimulationIteration(time_point=TimePoint(time_us=1629836933499518), index=60)
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 5.998992919921875
# hi 6.099045038223267
# SimulationIteration(time_point=TimePoint(time_us=1629836933599570), index=61)
# hi 6.099045038223267
# hi 6.099045038223267
# hi 6.099045038223267
# hi 6.099045038223267
# hi 6.099045038223267
# hi 6.099045038223267
# hi 6.099045038223267
# hi 6.099045038223267
# hi 6.099045038223267
# hi 6.19911003112793
# SimulationIteration(time_point=TimePoint(time_us=1629836933699635), index=62)
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.19911003112793
# hi 6.299175977706909
# SimulationIteration(time_point=TimePoint(time_us=1629836933799701), index=63)
# hi 6.299175977706909
# hi 6.299175977706909
# hi 6.299175977706909
# hi 6.299175977706909
# hi 6.299175977706909
# hi 6.299175977706909
# hi 6.299175977706909
# hi 6.299175977706909
# hi 6.299175977706909
# hi 6.399231910705566
# SimulationIteration(time_point=TimePoint(time_us=1629836933899757), index=64)
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.399231910705566
# hi 6.499269008636475
# SimulationIteration(time_point=TimePoint(time_us=1629836933999794), index=65)
# hi 6.499269008636475
# hi 6.499269008636475
# hi 6.499269008636475
# hi 6.499269008636475
# hi 6.499269008636475
# hi 6.499269008636475
# hi 6.499269008636475
# hi 6.499269008636475
# hi 6.499269008636475
# hi 6.59929084777832
# SimulationIteration(time_point=TimePoint(time_us=1629836934099816), index=66)
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.59929084777832
# hi 6.699307918548584
# SimulationIteration(time_point=TimePoint(time_us=1629836934199833), index=67)
# hi 6.699307918548584
# hi 6.699307918548584
# hi 6.699307918548584
# hi 6.699307918548584
# hi 6.699307918548584
# hi 6.699307918548584
# hi 6.699307918548584
# hi 6.699307918548584
# hi 6.699307918548584
# hi 6.799317836761475
# SimulationIteration(time_point=TimePoint(time_us=1629836934299843), index=68)
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.799317836761475
# hi 6.899328947067261
# SimulationIteration(time_point=TimePoint(time_us=1629836934399854), index=69)
# hi 6.899328947067261
# hi 6.899328947067261
# hi 6.899328947067261
# hi 6.899328947067261
# hi 6.899328947067261
# hi 6.899328947067261
# hi 6.899328947067261
# hi 6.899328947067261
# hi 6.899328947067261
# hi 6.999330043792725
# SimulationIteration(time_point=TimePoint(time_us=1629836934499855), index=70)
# hi 6.999330043792725
# hi 6.999330043792725
# hi 6.999330043792725
# hi 6.999330043792725
# hi 6.999330043792725
# hi 6.999330043792725
# hi 6.999330043792725
# hi 6.999330043792725
# hi 7.099313974380493
# SimulationIteration(time_point=TimePoint(time_us=1629836934599839), index=71)
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.099313974380493
# hi 7.19930100440979
# SimulationIteration(time_point=TimePoint(time_us=1629836934699826), index=72)
# hi 7.19930100440979
# hi 7.19930100440979
# hi 7.19930100440979
# hi 7.19930100440979
# hi 7.19930100440979
# hi 7.19930100440979
# hi 7.19930100440979
# hi 7.19930100440979
# hi 7.19930100440979
# hi 7.299294948577881
# SimulationIteration(time_point=TimePoint(time_us=1629836934799820), index=73)
# hi 7.299294948577881
# hi 7.299294948577881
# hi 7.299294948577881
# hi 7.299294948577881
# hi 7.299294948577881
# hi 7.299294948577881
# hi 7.299294948577881
# hi 7.299294948577881
# hi 7.399282932281494
# SimulationIteration(time_point=TimePoint(time_us=1629836934899808), index=74)
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.399282932281494
# hi 7.499269008636475
# SimulationIteration(time_point=TimePoint(time_us=1629836934999794), index=75)
# hi 7.499269008636475
# hi 7.499269008636475
# hi 7.499269008636475
# hi 7.499269008636475
# hi 7.499269008636475
# hi 7.499269008636475
# hi 7.499269008636475
# hi 7.499269008636475
# hi 7.499269008636475
# hi 7.599254846572876
# SimulationIteration(time_point=TimePoint(time_us=1629836935099780), index=76)
# hi 7.599254846572876
# hi 7.599254846572876
# hi 7.599254846572876
# hi 7.599254846572876
# hi 7.599254846572876
# hi 7.599254846572876
# hi 7.599254846572876
# hi 7.599254846572876
# hi 7.699239015579224
# SimulationIteration(time_point=TimePoint(time_us=1629836935199764), index=77)
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.699239015579224
# hi 7.79922890663147
# SimulationIteration(time_point=TimePoint(time_us=1629836935299754), index=78)
# hi 7.79922890663147
# hi 7.79922890663147
# hi 7.79922890663147
# hi 7.79922890663147
# hi 7.79922890663147
# hi 7.79922890663147
# hi 7.79922890663147
# hi 7.79922890663147
# hi 7.899226903915405
# SimulationIteration(time_point=TimePoint(time_us=1629836935399752), index=79)
# hi 7.899226903915405
# hi 7.899226903915405
# hi 7.899226903915405
# hi 7.899226903915405
# hi 7.899226903915405
# hi 7.899226903915405
# hi 7.899226903915405
# hi 7.899226903915405
# hi 7.999227046966553
# SimulationIteration(time_point=TimePoint(time_us=1629836935499752), index=80)
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 7.999227046966553
# hi 8.099222898483276
# SimulationIteration(time_point=TimePoint(time_us=1629836935599748), index=81)
# hi 8.099222898483276
# hi 8.099222898483276
# hi 8.099222898483276
# hi 8.099222898483276
# hi 8.099222898483276
# hi 8.099222898483276
# hi 8.099222898483276
# hi 8.099222898483276
# hi 8.099222898483276
# hi 8.199213027954102
# SimulationIteration(time_point=TimePoint(time_us=1629836935699738), index=82)
# hi 8.199213027954102
# hi 8.199213027954102
# hi 8.199213027954102
# hi 8.199213027954102
# hi 8.199213027954102
# hi 8.199213027954102
# hi 8.199213027954102
# hi 8.199213027954102
# hi 8.199213027954102
# hi 8.299196004867554
# SimulationIteration(time_point=TimePoint(time_us=1629836935799721), index=83)
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.299196004867554
# hi 8.399169921875
# SimulationIteration(time_point=TimePoint(time_us=1629836935899695), index=84)
# hi 8.399169921875
# hi 8.399169921875
# hi 8.399169921875
# hi 8.399169921875
# hi 8.399169921875
# hi 8.399169921875
# hi 8.399169921875
# hi 8.399169921875
# hi 8.399169921875
# hi 8.49914002418518
# SimulationIteration(time_point=TimePoint(time_us=1629836935999665), index=85)
# hi 8.49914002418518
# hi 8.49914002418518
# hi 8.49914002418518
# hi 8.49914002418518
# hi 8.49914002418518
# hi 8.49914002418518
# hi 8.49914002418518
# hi 8.49914002418518
# hi 8.49914002418518
# hi 8.59911298751831
# SimulationIteration(time_point=TimePoint(time_us=1629836936099638), index=86)
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.59911298751831
# hi 8.699082851409912
# SimulationIteration(time_point=TimePoint(time_us=1629836936199608), index=87)
# hi 8.699082851409912
# hi 8.699082851409912
# hi 8.699082851409912
# hi 8.699082851409912
# hi 8.699082851409912
# hi 8.699082851409912
# hi 8.699082851409912
# hi 8.699082851409912
# hi 8.699082851409912
# hi 8.799057960510254
# SimulationIteration(time_point=TimePoint(time_us=1629836936299583), index=88)
# hi 8.799057960510254
# hi 8.799057960510254
# hi 8.799057960510254
# hi 8.799057960510254
# hi 8.799057960510254
# hi 8.799057960510254
# hi 8.799057960510254
# hi 8.799057960510254
# hi 8.799057960510254
# hi 8.799057960510254
# hi 8.8990318775177
# SimulationIteration(time_point=TimePoint(time_us=1629836936399557), index=89)
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.8990318775177
# hi 8.999008893966675
# SimulationIteration(time_point=TimePoint(time_us=1629836936499534), index=90)
# hi 8.999008893966675
# hi 8.999008893966675
# hi 8.999008893966675
# hi 8.999008893966675
# hi 8.999008893966675
# hi 8.999008893966675
# hi 8.999008893966675
# hi 8.999008893966675
# hi 8.999008893966675
# hi 8.999008893966675
# hi 9.098992824554443
# SimulationIteration(time_point=TimePoint(time_us=1629836936599518), index=91)
# hi 9.098992824554443
# hi 9.098992824554443
# hi 9.098992824554443
# hi 9.098992824554443
# hi 9.098992824554443
# hi 9.098992824554443
# hi 9.098992824554443
# hi 9.098992824554443
# hi 9.098992824554443
# hi 9.098992824554443
# hi 9.198981046676636
# SimulationIteration(time_point=TimePoint(time_us=1629836936699506), index=92)
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.198981046676636
# hi 9.298969030380249
# SimulationIteration(time_point=TimePoint(time_us=1629836936799494), index=93)
# hi 9.298969030380249
# hi 9.298969030380249
# hi 9.298969030380249
# hi 9.298969030380249
# hi 9.298969030380249
# hi 9.298969030380249
# hi 9.298969030380249
# hi 9.298969030380249
# hi 9.298969030380249
# hi 9.298969030380249
# hi 9.398952007293701
# SimulationIteration(time_point=TimePoint(time_us=1629836936899477), index=94)
# hi 9.398952007293701
# hi 9.398952007293701
# hi 9.398952007293701
# hi 9.398952007293701
# hi 9.398952007293701
# hi 9.398952007293701
# hi 9.398952007293701
# hi 9.398952007293701
# hi 9.398952007293701
# hi 9.398952007293701
# hi 9.498934030532837
# SimulationIteration(time_point=TimePoint(time_us=1629836936999459), index=95)
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.498934030532837
# hi 9.598917007446289
# SimulationIteration(time_point=TimePoint(time_us=1629836937099442), index=96)
# hi 9.598917007446289
# hi 9.598917007446289
# hi 9.598917007446289
# hi 9.598917007446289
# hi 9.598917007446289
# hi 9.598917007446289
# hi 9.598917007446289
# hi 9.598917007446289
# hi 9.598917007446289
# hi 9.598917007446289
# hi 9.69891095161438
# SimulationIteration(time_point=TimePoint(time_us=1629836937199436), index=97)
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.69891095161438
# hi 9.79892086982727
# SimulationIteration(time_point=TimePoint(time_us=1629836937299446), index=98)
# hi 9.79892086982727
# hi 9.79892086982727
# hi 9.79892086982727
# hi 9.79892086982727
# hi 9.79892086982727
# hi 9.79892086982727
# hi 9.79892086982727
# hi 9.79892086982727
# hi 9.79892086982727
# hi 9.79892086982727
# hi 9.898948907852173
# SimulationIteration(time_point=TimePoint(time_us=1629836937399474), index=99)
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.898948907852173
# hi 9.998991966247559
# SimulationIteration(time_point=TimePoint(time_us=1629836937499517), index=100)
# hi 9.998991966247559
# hi 9.998991966247559
# hi 9.998991966247559
# hi 9.998991966247559
# hi 9.998991966247559
# hi 9.998991966247559
# hi 9.998991966247559
# hi 9.998991966247559
# hi 9.998991966247559
# hi 10.099045038223267
# SimulationIteration(time_point=TimePoint(time_us=1629836937599570), index=101)
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.099045038223267
# hi 10.199106931686401
# SimulationIteration(time_point=TimePoint(time_us=1629836937699632), index=102)
# hi 10.199106931686401
# hi 10.199106931686401
# hi 10.199106931686401
# hi 10.199106931686401
# hi 10.199106931686401
# hi 10.199106931686401
# hi 10.199106931686401
# hi 10.199106931686401
# hi 10.199106931686401
# hi 10.199106931686401
# hi 10.299170017242432
# SimulationIteration(time_point=TimePoint(time_us=1629836937799695), index=103)
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.299170017242432
# hi 10.399231910705566
# SimulationIteration(time_point=TimePoint(time_us=1629836937899757), index=104)
# hi 10.399231910705566
# hi 10.399231910705566
# hi 10.399231910705566
# hi 10.399231910705566
# hi 10.399231910705566
# hi 10.399231910705566
# hi 10.399231910705566
# hi 10.399231910705566
# hi 10.399231910705566
# hi 10.399231910705566
# hi 10.499300003051758
# SimulationIteration(time_point=TimePoint(time_us=1629836937999825), index=105)
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.499300003051758
# hi 10.59936785697937
# SimulationIteration(time_point=TimePoint(time_us=1629836938099893), index=106)
# hi 10.59936785697937
# hi 10.59936785697937
# hi 10.59936785697937
# hi 10.59936785697937
# hi 10.59936785697937
# hi 10.59936785697937
# hi 10.59936785697937
# hi 10.59936785697937
# hi 10.59936785697937
# hi 10.59936785697937
# hi 10.699432849884033
# SimulationIteration(time_point=TimePoint(time_us=1629836938199958), index=107)
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.699432849884033
# hi 10.799485921859741
# SimulationIteration(time_point=TimePoint(time_us=1629836938300011), index=108)
# hi 10.799485921859741
# hi 10.799485921859741
# hi 10.799485921859741
# hi 10.799485921859741
# hi 10.799485921859741
# hi 10.799485921859741
# hi 10.799485921859741
# hi 10.799485921859741
# hi 10.799485921859741
# hi 10.799485921859741
# hi 10.899533033370972
# SimulationIteration(time_point=TimePoint(time_us=1629836938400058), index=109)
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.899533033370972
# hi 10.999572992324829
# ...
# hi 11.099609851837158
# hi 11.099609851837158
# hi 11.099609851837158
# hi 11.099609851837158
# hi 11.199641942977905
# SimulationIteration(time_point=TimePoint(time_us=1629836938700167), index=112)
# hi 11.199641942977905
# hi 11.199641942977905
# hi 11.199641942977905
# hi 11.199641942977905
# hi 11.199641942977905
# hi 11.199641942977905
# hi 11.199641942977905
# hi 11.199641942977905
# hi 11.199641942977905
# hi 11.199641942977905
# hi 11.299674987792969
# SimulationIteration(time_point=TimePoint(time_us=1629836938800200), index=113)
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.299674987792969
# hi 11.399709939956665
# SimulationIteration(time_point=TimePoint(time_us=1629836938900235), index=114)
# hi 11.399709939956665
# hi 11.399709939956665
# hi 11.399709939956665
# hi 11.399709939956665
# hi 11.399709939956665
# hi 11.399709939956665
# hi 11.399709939956665
# hi 11.399709939956665
# hi 11.399709939956665
# hi 11.399709939956665
# hi 11.499745845794678
# SimulationIteration(time_point=TimePoint(time_us=1629836939000271), index=115)
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.499745845794678
# hi 11.599776029586792
# SimulationIteration(time_point=TimePoint(time_us=1629836939100301), index=116)
# hi 11.599776029586792
# hi 11.599776029586792
# hi 11.599776029586792
# hi 11.599776029586792
# hi 11.599776029586792
# hi 11.599776029586792
# hi 11.599776029586792
# hi 11.599776029586792
# hi 11.599776029586792
# hi 11.599776029586792
# hi 11.699790954589844
# SimulationIteration(time_point=TimePoint(time_us=1629836939200316), index=117)
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.699790954589844
# hi 11.799794912338257
# SimulationIteration(time_point=TimePoint(time_us=1629836939300320), index=118)
# hi 11.799794912338257
# hi 11.799794912338257
# hi 11.799794912338257
# hi 11.799794912338257
# hi 11.799794912338257
# hi 11.799794912338257
# hi 11.799794912338257
# hi 11.799794912338257
# hi 11.899776935577393
# SimulationIteration(time_point=TimePoint(time_us=1629836939400302), index=119)
# hi 11.899776935577393
# hi 11.899776935577393
# hi 11.899776935577393
# hi 11.899776935577393
# hi 11.899776935577393
# hi 11.899776935577393
# hi 11.899776935577393
# hi 11.899776935577393
# hi 11.899776935577393
# hi 11.899776935577393
# hi 11.999737977981567
# SimulationIteration(time_point=TimePoint(time_us=1629836939500263), index=120)
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 11.999737977981567
# hi 12.099685907363892
# SimulationIteration(time_point=TimePoint(time_us=1629836939600211), index=121)
# hi 12.099685907363892
# hi 12.099685907363892
# hi 12.099685907363892
# hi 12.099685907363892
# hi 12.099685907363892
# hi 12.099685907363892
# hi 12.099685907363892
# hi 12.099685907363892
# hi 12.199625015258789
# SimulationIteration(time_point=TimePoint(time_us=1629836939700150), index=122)
# hi 12.199625015258789
# hi 12.199625015258789
# hi 12.199625015258789
# hi 12.199625015258789
# hi 12.199625015258789
# hi 12.199625015258789
# hi 12.199625015258789
# hi 12.199625015258789
# hi 12.199625015258789
# hi 12.199625015258789
# hi 12.299554824829102
# SimulationIteration(time_point=TimePoint(time_us=1629836939800080), index=123)
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.299554824829102
# hi 12.399475812911987
# SimulationIteration(time_point=TimePoint(time_us=1629836939900001), index=124)
# hi 12.399475812911987
# hi 12.399475812911987
# hi 12.399475812911987
# hi 12.399475812911987
# hi 12.399475812911987
# hi 12.399475812911987
# hi 12.399475812911987
# hi 12.399475812911987
# hi 12.499397993087769
# SimulationIteration(time_point=TimePoint(time_us=1629836939999923), index=125)
# hi 12.499397993087769
# hi 12.499397993087769
# hi 12.499397993087769
# hi 12.499397993087769
# hi 12.499397993087769
# hi 12.499397993087769
# hi 12.499397993087769
# hi 12.499397993087769
# hi 12.499397993087769
# hi 12.499397993087769
# hi 12.59932804107666
# SimulationIteration(time_point=TimePoint(time_us=1629836940099853), index=126)
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.59932804107666
# hi 12.699260950088501
# SimulationIteration(time_point=TimePoint(time_us=1629836940199786), index=127)
# hi 12.699260950088501
# hi 12.699260950088501
# hi 12.699260950088501
# hi 12.699260950088501
# hi 12.699260950088501
# hi 12.699260950088501
# hi 12.699260950088501
# hi 12.699260950088501
# hi 12.799206018447876
# SimulationIteration(time_point=TimePoint(time_us=1629836940299731), index=128)
# hi 12.799206018447876
# hi 12.799206018447876
# hi 12.799206018447876
# hi 12.799206018447876
# hi 12.799206018447876
# hi 12.799206018447876
# hi 12.799206018447876
# hi 12.799206018447876
# hi 12.799206018447876
# hi 12.799206018447876
# hi 12.899158954620361
# SimulationIteration(time_point=TimePoint(time_us=1629836940399684), index=129)
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.899158954620361
# hi 12.999109983444214
# SimulationIteration(time_point=TimePoint(time_us=1629836940499635), index=130)
# hi 12.999109983444214
# hi 12.999109983444214
# hi 12.999109983444214
# hi 12.999109983444214
# hi 12.999109983444214
# hi 12.999109983444214
# hi 12.999109983444214
# hi 12.999109983444214
# hi 13.099057912826538
# SimulationIteration(time_point=TimePoint(time_us=1629836940599583), index=131)
# hi 13.099057912826538
# hi 13.099057912826538
# hi 13.099057912826538
# hi 13.099057912826538
# hi 13.099057912826538
# hi 13.099057912826538
# hi 13.099057912826538
# hi 13.099057912826538
# hi 13.099057912826538
# hi 13.099057912826538
# hi 13.199004888534546
# SimulationIteration(time_point=TimePoint(time_us=1629836940699530), index=132)
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.199004888534546
# hi 13.298947811126709
# SimulationIteration(time_point=TimePoint(time_us=1629836940799473), index=133)
# hi 13.298947811126709
# hi 13.298947811126709
# hi 13.298947811126709
# hi 13.298947811126709
# hi 13.298947811126709
# hi 13.298947811126709
# hi 13.298947811126709
# hi 13.298947811126709
# hi 13.398890972137451
# SimulationIteration(time_point=TimePoint(time_us=1629836940899416), index=134)
# hi 13.398890972137451
# hi 13.398890972137451
# hi 13.398890972137451
# hi 13.398890972137451
# hi 13.398890972137451
# hi 13.398890972137451
# hi 13.398890972137451
# hi 13.398890972137451
# hi 13.398890972137451
# hi 13.398890972137451
# hi 13.49883484840393
# SimulationIteration(time_point=TimePoint(time_us=1629836940999360), index=135)
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.49883484840393
# hi 13.59879183769226
# SimulationIteration(time_point=TimePoint(time_us=1629836941099317), index=136)
# hi 13.59879183769226
# hi 13.59879183769226
# hi 13.59879183769226
# hi 13.59879183769226
# hi 13.59879183769226
# hi 13.59879183769226
# hi 13.59879183769226
# hi 13.59879183769226
# hi 13.698766946792603
# SimulationIteration(time_point=TimePoint(time_us=1629836941199292), index=137)
# hi 13.698766946792603
# hi 13.698766946792603
# hi 13.698766946792603
# hi 13.698766946792603
# hi 13.698766946792603
# hi 13.698766946792603
# hi 13.698766946792603
# hi 13.698766946792603
# hi 13.698766946792603
# hi 13.698766946792603
# hi 13.798758029937744
# SimulationIteration(time_point=TimePoint(time_us=1629836941299283), index=138)
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.798758029937744
# hi 13.898775815963745
# SimulationIteration(time_point=TimePoint(time_us=1629836941399301), index=139)
# hi 13.898775815963745
# hi 13.898775815963745
# hi 13.898775815963745
# hi 13.898775815963745
# hi 13.898775815963745
# hi 13.898775815963745
# hi 13.898775815963745
# hi 13.898775815963745
# hi 13.898775815963745
# hi 13.898775815963745
# hi 13.998819828033447
# SimulationIteration(time_point=TimePoint(time_us=1629836941499345), index=140)
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 13.998819828033447
# hi 14.098872900009155
# SimulationIteration(time_point=TimePoint(time_us=1629836941599398), index=141)
# hi 14.098872900009155
# hi 14.098872900009155
# hi 14.098872900009155
# hi 14.098872900009155
# hi 14.098872900009155
# hi 14.098872900009155
# hi 14.098872900009155
# hi 14.098872900009155
# hi 14.098872900009155
# hi 14.098872900009155
# hi 14.198936939239502
# SimulationIteration(time_point=TimePoint(time_us=1629836941699462), index=142)
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.198936939239502
# hi 14.299012899398804
# SimulationIteration(time_point=TimePoint(time_us=1629836941799538), index=143)
# hi 14.299012899398804
# hi 14.299012899398804
# hi 14.299012899398804
# hi 14.299012899398804
# hi 14.299012899398804
# hi 14.299012899398804
# hi 14.299012899398804
# hi 14.299012899398804
# hi 14.299012899398804
# hi 14.299012899398804
# hi 14.399083852767944
# SimulationIteration(time_point=TimePoint(time_us=1629836941899609), index=144)
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.399083852767944
# hi 14.499155044555664
# SimulationIteration(time_point=TimePoint(time_us=1629836941999680), index=145)
# hi 14.499155044555664
# hi 14.499155044555664
# hi 14.499155044555664
# hi 14.499155044555664
# hi 14.499155044555664
# hi 14.499155044555664
# hi 14.499155044555664
# hi 14.499155044555664
# hi 14.499155044555664
# hi 14.499155044555664
# hi 14.599212884902954
# SimulationIteration(time_point=TimePoint(time_us=1629836942099738), index=146)
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.599212884902954
# hi 14.699270963668823
# SimulationIteration(time_point=TimePoint(time_us=1629836942199796), index=147)
# hi 14.699270963668823
# hi 14.699270963668823
# hi 14.699270963668823
# hi 14.699270963668823
# hi 14.699270963668823
# hi 14.699270963668823
# hi 14.699270963668823
# hi 14.699270963668823
# hi 14.699270963668823
# hi 14.699270963668823
# hi 14.799338817596436
# SimulationIteration(time_point=TimePoint(time_us=1629836942299864), index=148)

# %%
scenario_builder = "val"  # [nuplan (uses trainval), nuplan_mini, test, val, train_boston, train_pittsburgh, train_singapore]
# output_folder = "../../data/nuplan/exp/exp/simulation/open_loop_boxes/2023.12.31.02.58.31"

# output_folder = (
#     "../../data/nuplan/exp/exp/simulation/open_loop_boxes/2023.12.31.05.00.39"
# )

output_folder = (
    "../../data/nuplan/exp/exp/simulation/closed_loop_multiagent/2024.01.02.11.51.20"
)


# without injection
# output_folder = "../../data/nuplan/exp/exp/simulation/closed_loop_multiagent/2024.01.02.00.44.56"

# with injection
# output_folder = (
#     "../../data/nuplan/exp/exp/simulation/closed_loop_multiagent/2024.01.02.02.37.00"
# )

# output_folder = (
#     "../../data/nuplan/exp/exp/simulation/open_loop_boxes/2023.12.20.13.59.34"
# )
# output_folder = '../../data/nuplan/exp/exp/simulation/open_loop_boxes/2023.12.09.21.19.06'
# output_folder = "../../data/nuplan/exp/exp/simulation/closed_loop_reactive_agents/2023.12.09.21.59.48"
# Location of path with all nuBoard configs
CONFIG_PATH = "../nuplan/planning/script/config/nuboard"
CONFIG_NAME = "default_nuboard"

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(
    config_name=CONFIG_NAME,
    overrides=[
        f"scenario_builder={scenario_builder}",  # set the database (same as simulation) used to fetch data for visualization
        f"simulation_path={output_folder}",  # [output_folder, output_folder_alt] nuboard file path(s), if left empty the user can open the file inside nuBoard
    ],
)

# %%
from nuplan.planning.script.run_nuboard import main as main_nuboard

# Run nuBoard
main_nuboard(cfg)
# Out:
# INFO:nuplan.planning.script.builders.scenario_building_builder:Building AbstractScenarioBuilder...
# INFO:nuplan.planning.script.builders.scenario_building_builder:Building AbstractScenarioBuilder...DONE!
# INFO:nuplan.planning.nuboard.nuboard:Opening Bokeh application on http://localhost:5006/
# INFO:nuplan.planning.nuboard.nuboard:Async rendering is set to: True
# INFO:bokeh.server.server:Starting Bokeh server version 2.4.3 (running on Tornado 6.3.3)
# WARNING:bokeh.server.util:Host wildcard '*' will allow connections originating from multiple (or possibly all) hostnames or IPs. Use non-wildcard values to restrict access explicitly
# INFO:bokeh.server.tornado:User authentication hooks NOT provided (default user enabled)
# INFO:nuplan.planning.nuboard.base.experiment_file_data:Could not open Parquet input source '<Buffer>': Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.
# INFO:nuplan.planning.nuboard.base.simulation_tile:Minimum frame time=0.017 s
# INFO:nuplan.planning.nuboard.tabs.scenario_tab:Rending scenario plot takes 0.0005 seconds.
# INFO:tornado.access:200 GET / (127.0.0.1) 383.31ms
# INFO:tornado.access:200 GET / (127.0.0.1) 383.31ms
# INFO:tornado.access:101 GET /ws (127.0.0.1) 0.50ms
# INFO:tornado.access:101 GET /ws (127.0.0.1) 0.50ms
# INFO:bokeh.server.views.ws:WebSocket connection opened
# INFO:bokeh.server.views.ws:ServerConnection created
# INFO:nuplan.planning.nuboard.base.experiment_file_data:Could not open Parquet input source '<Buffer>': Parquet magic bytes not found in footer. Either the file is corrupted or this is not a parquet file.
# INFO:nuplan.planning.nuboard.base.simulation_tile:Minimum frame time=0.017 s
# INFO:nuplan.planning.nuboard.tabs.scenario_tab:Rending scenario plot takes 0.0004 seconds.
# INFO:tornado.access:200 GET / (127.0.0.1) 103.78ms
# INFO:tornado.access:200 GET / (127.0.0.1) 103.78ms
# Rendering a scenario: 100%|██████████| 1/1 [00:00<00:00, 35.80it/s]
# INFO:nuplan.planning.nuboard.tabs.scenario_tab:Rending scenario plot takes 5.1503 seconds.

# %%
from tutorials.utils.tutorial_utils import visualize_history

from IPython.core.display import display, HTML
from bokeh.io import output_notebook
# Out:
# /tmp/ipykernel_2434612/3982088180.py:3: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
nest_asyncio.apply()
output_notebook()
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2070">Loading BokehJS ...</span>
#     </div>
# <style>.output_result { max-width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %%
visualize_history(runner.simulation._history, runner.scenario, bokeh_port=5006)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/ehdykhne/nuplan-devkit/experiments/test_notebook.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bwisedave.eng.uwaterloo.ca/home/ehdykhne/nuplan-devkit/experiments/test_notebook.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> visualize_history(runner.simulation._history, runner.scenario, bokeh_port=5006)
#
# NameError: name 'visualize_history' is not defined
